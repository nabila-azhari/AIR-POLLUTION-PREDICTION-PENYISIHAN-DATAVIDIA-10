# %%
import pandas as pd
from pathlib import Path


INPUT_DIR = Path(r"C:\Users\USER\Desktop\DATAVIDIA\penyisihan-datavidia-10\ISPU")

# %%
dfs = []

for file in sorted(INPUT_DIR.glob("*.csv")):
    df = pd.read_csv(file)
    print(f"{file.name}: {df.shape[0]} rows")
# Out:
# data-indeks-standar-pencemar-udara-(ispu)-di-provinsi-dki-jakarta-2023-komponen-data.csv: 1825 rows
# data-indeks-standar-pencemar-udara-(ispu)-di-provinsi-dki-jakarta-komponen-data-2024.csv: 1830 rows
# data-indeks-standar-pencemar-udara-(ispu)-di-provinsi-dki-jakarta-komponen-data-2025.csv: 1215 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2010-komponen-data.csv: 1825 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2011-komponen-data.csv: 365 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2012-komponen-data.csv: 366 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2013-komponen-data.csv: 365 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2014-komponen-data.csv: 1825 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2015-komponen-data.csv: 365 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2016-komponen-data.csv: 1830 rows
# indeks-standar-pencemaran-udara-(ispu)-tahun-2017-komponen-data.csv: 1825 rows
# ...
