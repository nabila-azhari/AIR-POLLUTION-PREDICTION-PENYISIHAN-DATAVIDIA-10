# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np
from IPython.display import display




NA_VALUES = ["---", "--", "", " ", "NA", "N/A"]
# =========================
# FILE FINDER
# =========================
def find_file(name, start=Path.cwd()):
    for ancestor in [start] + list(start.parents):
        matches = list(ancestor.rglob(name))
        if matches:
            return matches[0]
    return None


def find_files(file_map):
    found = {}
    for key, filename in file_map.items():
        path = find_file(filename)
        if path:
            found[key] = path
        else:
            print(f"[WARNING] File not found: {filename}")
    return found

eda_script_path = find_file("script_eda.py")
if eda_script_path is None:
    raise FileNotFoundError("❌ script_eda.py tidak ditemukan di parent directory")

# tambahkan BASE PROJECT ke sys.path
sys.path.append(str(eda_script_path.parent))

# sekarang bisa import
from script_eda import evaluate_dataset, extract_column_schema,find_internal_duplicate_columns,extract_single_schema

path_merged_data = find_file("cuaca_harian_dki_processed.csv")

if path_merged_data is None:
    raise FileNotFoundError("❌ File merged tidak ditemukan")

df_cuaca = pd.read_csv(path_merged_data, na_values=NA_VALUES)

evaluate_dataset(
    df_cuaca,
    name="Cuaca Harian DKI (Processed)",
    unique=["time", "lokasi"]
)
# Out:
# ================ Cuaca Harian DKI (Processed) ================
#          time  temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0  2010-01-01                     29.4                     24.4
# 1  2010-01-02                     30.8                     24.0
# 2  2010-01-03                     30.4                     24.3
# 3  2010-01-04                     30.3                     25.4
# 4  2010-01-05                     29.9                     24.8
#
#    precipitation_sum (mm)  precipitation_hours (h)  wind_speed_10m_max (km/h)  \
# 0                     4.0                     14.0                       16.0
# 1                     6.5                      4.0                       14.7
# 2                     7.6                     11.0                       12.6
# 3                     0.9                      5.0                       19.3
# 4                    14.3                      7.0                       15.9
#
#    wind_direction_10m_dominant (°)  shortwave_radiation_sum (MJ/m²)  \
# 0                              246                            16.24
# 1                              238                            19.80
# 2                              244                            17.32
# 3                              239                            20.43
# 4                              247                            15.86
#
#    temperature_2m_mean (°C)  relative_humidity_2m_mean (%)  ...  \
# 0                      26.6                             81  ...
# 1                      26.9                             82  ...
# 2                      26.7                             83  ...
# 3                      27.4                             81  ...
# 4                      26.4                             83  ...
#
#    relative_humidity_2m_min (%)  cloud_cover_max (%)  cloud_cover_min (%)  \
# 0                            69                  100                   99
# 1                            69                  100                   91
# 2                            70                  100                   81
# 3                            70                  100                   17
# 4                            72                  100                   99
#
#    wind_gusts_10m_mean (km/h)  wind_speed_10m_mean (km/h)  \
# 0                        21.0                        10.5
# 1                        16.5                         7.7
# 2                        18.4                         9.4
# 3                        23.8                        13.5
# 4                        21.6                        11.1
#
#    wind_gusts_10m_min (km/h)  wind_speed_10m_min (km/h)  \
# 0                       11.9                        6.9
# 1                        9.0                        4.4
# 2                       11.9                        6.5
# 3                       14.4                        9.6
# 4                       10.4                        7.8
#
#    surface_pressure_max (hPa)  surface_pressure_min (hPa)           lokasi
# 0                      1009.3                      1005.1  dki1_bundaranhi
# 1                      1009.9                      1006.0  dki1_bundaranhi
# 2                      1010.5                      1006.5  dki1_bundaranhi
# 3                      1009.1                      1005.1  dki1_bundaranhi
# 4                      1009.1                      1006.0  dki1_bundaranhi
#
# [5 rows x 25 columns]
# 📌 Columns:
# <style type="text/css">
# #T_92812 th.row_heading {
#   text-align: left;
# }
# #T_92812  th.col_heading {
#   text-align: left;
# }
# #T_92812 td {
#   text-align: right;
# }
# </style>
# <table id="T_92812">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92812_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_92812_level0_col1" class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92812_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92812_row0_col0" class="data row0 col0" >time</td>
#       <td id="T_92812_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92812_row1_col0" class="data row1 col0" >temperature_2m_max (°C)</td>
#       <td id="T_92812_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92812_row2_col0" class="data row2 col0" >temperature_2m_min (°C)</td>
#       <td id="T_92812_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92812_row3_col0" class="data row3 col0" >precipitation_sum (mm)</td>
#       <td id="T_92812_row3_col1" class="data row3 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92812_row4_col0" class="data row4 col0" >precipitation_hours (h)</td>
#       <td id="T_92812_row4_col1" class="data row4 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92812_row5_col0" class="data row5 col0" >wind_speed_10m_max (km/h)</td>
#       <td id="T_92812_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92812_row6_col0" class="data row6 col0" >wind_direction_10m_dominant (°)</td>
#       <td id="T_92812_row6_col1" class="data row6 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92812_row7_col0" class="data row7 col0" >shortwave_radiation_sum (MJ/m²)</td>
#       <td id="T_92812_row7_col1" class="data row7 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_92812_row8_col0" class="data row8 col0" >temperature_2m_mean (°C)</td>
#       <td id="T_92812_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_92812_row9_col0" class="data row9 col0" >relative_humidity_2m_mean (%)</td>
#       <td id="T_92812_row9_col1" class="data row9 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_92812_row10_col0" class="data row10 col0" >cloud_cover_mean (%)</td>
#       <td id="T_92812_row10_col1" class="data row10 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_92812_row11_col0" class="data row11 col0" >surface_pressure_mean (hPa)</td>
#       <td id="T_92812_row11_col1" class="data row11 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_92812_row12_col0" class="data row12 col0" >wind_gusts_10m_max (km/h)</td>
#       <td id="T_92812_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_92812_row13_col0" class="data row13 col0" >winddirection_10m_dominant (°)</td>
#       <td id="T_92812_row13_col1" class="data row13 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_92812_row14_col0" class="data row14 col0" >relative_humidity_2m_max (%)</td>
#       <td id="T_92812_row14_col1" class="data row14 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_92812_row15_col0" class="data row15 col0" >relative_humidity_2m_min (%)</td>
#       <td id="T_92812_row15_col1" class="data row15 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_92812_row16_col0" class="data row16 col0" >cloud_cover_max (%)</td>
#       <td id="T_92812_row16_col1" class="data row16 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_92812_row17_col0" class="data row17 col0" >cloud_cover_min (%)</td>
#       <td id="T_92812_row17_col1" class="data row17 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_92812_row18_col0" class="data row18 col0" >wind_gusts_10m_mean (km/h)</td>
#       <td id="T_92812_row18_col1" class="data row18 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_92812_row19_col0" class="data row19 col0" >wind_speed_10m_mean (km/h)</td>
#       <td id="T_92812_row19_col1" class="data row19 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_92812_row20_col0" class="data row20 col0" >wind_gusts_10m_min (km/h)</td>
#       <td id="T_92812_row20_col1" class="data row20 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_92812_row21_col0" class="data row21 col0" >wind_speed_10m_min (km/h)</td>
#       <td id="T_92812_row21_col1" class="data row21 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_92812_row22_col0" class="data row22 col0" >surface_pressure_max (hPa)</td>
#       <td id="T_92812_row22_col1" class="data row22 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_92812_row23_col0" class="data row23 col0" >surface_pressure_min (hPa)</td>
#       <td id="T_92812_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_92812_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_92812_row24_col0" class="data row24 col0" >lokasi</td>
#       <td id="T_92812_row24_col1" class="data row24 col1" >object</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Tidak ada data null
# ✅ Tidak ada data duplikat
# <style type="text/css">
# #T_130fc th.row_heading {
#   text-align: left;
# }
# #T_130fc  th.col_heading {
#   text-align: left;
# }
# #T_130fc td {
#   text-align: right;
# }
# </style>
# <table id="T_130fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_130fc_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_130fc_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_130fc_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_130fc_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_130fc_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_130fc_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_130fc_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_130fc_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_130fc_level0_row0" class="row_heading level0 row0" >temperature_2m_max (°C)</th>
#       <td id="T_130fc_row0_col0" class="data row0 col0" >28610.000000</td>
#       <td id="T_130fc_row0_col1" class="data row0 col1" >30.648399</td>
#       <td id="T_130fc_row0_col2" class="data row0 col2" >1.821691</td>
#       <td id="T_130fc_row0_col3" class="data row0 col3" >23.900000</td>
#       <td id="T_130fc_row0_col4" class="data row0 col4" >29.500000</td>
#       <td id="T_130fc_row0_col5" class="data row0 col5" >30.500000</td>
#       <td id="T_130fc_row0_col6" class="data row0 col6" >31.800000</td>
#       <td id="T_130fc_row0_col7" class="data row0 col7" >38.800000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row1" class="row_heading level0 row1" >temperature_2m_min (°C)</th>
#       <td id="T_130fc_row1_col0" class="data row1 col0" >28610.000000</td>
#       <td id="T_130fc_row1_col1" class="data row1 col1" >23.523957</td>
#       <td id="T_130fc_row1_col2" class="data row1 col2" >0.862093</td>
#       <td id="T_130fc_row1_col3" class="data row1 col3" >18.500000</td>
#       <td id="T_130fc_row1_col4" class="data row1 col4" >23.000000</td>
#       <td id="T_130fc_row1_col5" class="data row1 col5" >23.600000</td>
#       <td id="T_130fc_row1_col6" class="data row1 col6" >24.100000</td>
#       <td id="T_130fc_row1_col7" class="data row1 col7" >26.400000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row2" class="row_heading level0 row2" >precipitation_sum (mm)</th>
#       <td id="T_130fc_row2_col0" class="data row2 col0" >28610.000000</td>
#       <td id="T_130fc_row2_col1" class="data row2 col1" >6.499259</td>
#       <td id="T_130fc_row2_col2" class="data row2 col2" >7.959182</td>
#       <td id="T_130fc_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_130fc_row2_col4" class="data row2 col4" >0.800000</td>
#       <td id="T_130fc_row2_col5" class="data row2 col5" >3.800000</td>
#       <td id="T_130fc_row2_col6" class="data row2 col6" >9.600000</td>
#       <td id="T_130fc_row2_col7" class="data row2 col7" >117.700000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row3" class="row_heading level0 row3" >precipitation_hours (h)</th>
#       <td id="T_130fc_row3_col0" class="data row3 col0" >28610.000000</td>
#       <td id="T_130fc_row3_col1" class="data row3 col1" >8.126075</td>
#       <td id="T_130fc_row3_col2" class="data row3 col2" >5.980301</td>
#       <td id="T_130fc_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_130fc_row3_col4" class="data row3 col4" >3.000000</td>
#       <td id="T_130fc_row3_col5" class="data row3 col5" >7.000000</td>
#       <td id="T_130fc_row3_col6" class="data row3 col6" >12.000000</td>
#       <td id="T_130fc_row3_col7" class="data row3 col7" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row4" class="row_heading level0 row4" >wind_speed_10m_max (km/h)</th>
#       <td id="T_130fc_row4_col0" class="data row4 col0" >28610.000000</td>
#       <td id="T_130fc_row4_col1" class="data row4 col1" >12.591846</td>
#       <td id="T_130fc_row4_col2" class="data row4 col2" >3.652951</td>
#       <td id="T_130fc_row4_col3" class="data row4 col3" >4.100000</td>
#       <td id="T_130fc_row4_col4" class="data row4 col4" >9.800000</td>
#       <td id="T_130fc_row4_col5" class="data row4 col5" >12.000000</td>
#       <td id="T_130fc_row4_col6" class="data row4 col6" >14.900000</td>
#       <td id="T_130fc_row4_col7" class="data row4 col7" >30.400000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row5" class="row_heading level0 row5" >wind_direction_10m_dominant (°)</th>
#       <td id="T_130fc_row5_col0" class="data row5 col0" >28610.000000</td>
#       <td id="T_130fc_row5_col1" class="data row5 col1" >178.957987</td>
#       <td id="T_130fc_row5_col2" class="data row5 col2" >96.550651</td>
#       <td id="T_130fc_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_130fc_row5_col4" class="data row5 col4" >91.000000</td>
#       <td id="T_130fc_row5_col5" class="data row5 col5" >184.000000</td>
#       <td id="T_130fc_row5_col6" class="data row5 col6" >266.000000</td>
#       <td id="T_130fc_row5_col7" class="data row5 col7" >360.000000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row6" class="row_heading level0 row6" >shortwave_radiation_sum (MJ/m²)</th>
#       <td id="T_130fc_row6_col0" class="data row6 col0" >28610.000000</td>
#       <td id="T_130fc_row6_col1" class="data row6 col1" >18.486990</td>
#       <td id="T_130fc_row6_col2" class="data row6 col2" >3.800085</td>
#       <td id="T_130fc_row6_col3" class="data row6 col3" >2.540000</td>
#       <td id="T_130fc_row6_col4" class="data row6 col4" >16.570000</td>
#       <td id="T_130fc_row6_col5" class="data row6 col5" >19.090000</td>
#       <td id="T_130fc_row6_col6" class="data row6 col6" >21.060000</td>
#       <td id="T_130fc_row6_col7" class="data row6 col7" >27.980000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row7" class="row_heading level0 row7" >temperature_2m_mean (°C)</th>
#       <td id="T_130fc_row7_col0" class="data row7 col0" >28610.000000</td>
#       <td id="T_130fc_row7_col1" class="data row7 col1" >26.598972</td>
#       <td id="T_130fc_row7_col2" class="data row7 col2" >0.954853</td>
#       <td id="T_130fc_row7_col3" class="data row7 col3" >23.100000</td>
#       <td id="T_130fc_row7_col4" class="data row7 col4" >26.000000</td>
#       <td id="T_130fc_row7_col5" class="data row7 col5" >26.550000</td>
#       <td id="T_130fc_row7_col6" class="data row7 col6" >27.200000</td>
#       <td id="T_130fc_row7_col7" class="data row7 col7" >30.500000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row8" class="row_heading level0 row8" >relative_humidity_2m_mean (%)</th>
#       <td id="T_130fc_row8_col0" class="data row8 col0" >28610.000000</td>
#       <td id="T_130fc_row8_col1" class="data row8 col1" >81.814925</td>
#       <td id="T_130fc_row8_col2" class="data row8 col2" >7.013838</td>
#       <td id="T_130fc_row8_col3" class="data row8 col3" >50.000000</td>
#       <td id="T_130fc_row8_col4" class="data row8 col4" >78.000000</td>
#       <td id="T_130fc_row8_col5" class="data row8 col5" >84.000000</td>
#       <td id="T_130fc_row8_col6" class="data row8 col6" >87.000000</td>
#       <td id="T_130fc_row8_col7" class="data row8 col7" >96.000000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row9" class="row_heading level0 row9" >cloud_cover_mean (%)</th>
#       <td id="T_130fc_row9_col0" class="data row9 col0" >28610.000000</td>
#       <td id="T_130fc_row9_col1" class="data row9 col1" >77.760154</td>
#       <td id="T_130fc_row9_col2" class="data row9 col2" >22.281477</td>
#       <td id="T_130fc_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_130fc_row9_col4" class="data row9 col4" >64.000000</td>
#       <td id="T_130fc_row9_col5" class="data row9 col5" >85.000000</td>
#       <td id="T_130fc_row9_col6" class="data row9 col6" >97.000000</td>
#       <td id="T_130fc_row9_col7" class="data row9 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_130fc_level0_row10" class="row_heading level0 row10" >surface_pressure_mean (hPa)</th>
#       <td id="T_130fc_row10_col0

# %%
path_merged_data = find_file("cuaca_harian_dki_processed.csv")

if path_merged_data is None:
    raise FileNotFoundError("❌ File merged tidak ditemukan")

df_cuaca = pd.read_csv(path_merged_data, na_values=NA_VALUES)


evaluate_dataset(
    df_cuaca,
    name="Cuaca Harian DKI (Merged)",
    unique=["time", "lokasi"]
)
# Out:
# ================ Cuaca Harian DKI (Merged) ================
#          time  temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0  2010-01-01                     29.4                     24.4
# 1  2010-01-02                     30.8                     24.0
# 2  2010-01-03                     30.4                     24.3
# 3  2010-01-04                     30.3                     25.4
# 4  2010-01-05                     29.9                     24.8
#
#    precipitation_sum (mm)  precipitation_hours (h)  wind_speed_10m_max (km/h)  \
# 0                     4.0                     14.0                       16.0
# 1                     6.5                      4.0                       14.7
# 2                     7.6                     11.0                       12.6
# 3                     0.9                      5.0                       19.3
# 4                    14.3                      7.0                       15.9
#
#    wind_direction_10m_dominant (°)  shortwave_radiation_sum (MJ/m²)  \
# 0                              246                            16.24
# 1                              238                            19.80
# 2                              244                            17.32
# 3                              239                            20.43
# 4                              247                            15.86
#
#    temperature_2m_mean (°C)  relative_humidity_2m_mean (%)  ...  \
# 0                      26.6                             81  ...
# 1                      26.9                             82  ...
# 2                      26.7                             83  ...
# 3                      27.4                             81  ...
# 4                      26.4                             83  ...
#
#    relative_humidity_2m_min (%)  cloud_cover_max (%)  cloud_cover_min (%)  \
# 0                            69                  100                   99
# 1                            69                  100                   91
# 2                            70                  100                   81
# 3                            70                  100                   17
# 4                            72                  100                   99
#
#    wind_gusts_10m_mean (km/h)  wind_speed_10m_mean (km/h)  \
# 0                        21.0                        10.5
# 1                        16.5                         7.7
# 2                        18.4                         9.4
# 3                        23.8                        13.5
# 4                        21.6                        11.1
#
#    wind_gusts_10m_min (km/h)  wind_speed_10m_min (km/h)  \
# 0                       11.9                        6.9
# 1                        9.0                        4.4
# 2                       11.9                        6.5
# 3                       14.4                        9.6
# 4                       10.4                        7.8
#
#    surface_pressure_max (hPa)  surface_pressure_min (hPa)           lokasi
# 0                      1009.3                      1005.1  dki1_bundaranhi
# 1                      1009.9                      1006.0  dki1_bundaranhi
# 2                      1010.5                      1006.5  dki1_bundaranhi
# 3                      1009.1                      1005.1  dki1_bundaranhi
# 4                      1009.1                      1006.0  dki1_bundaranhi
#
# [5 rows x 25 columns]
# 📌 Columns:
# <style type="text/css">
# #T_fa285 th.row_heading {
#   text-align: left;
# }
# #T_fa285  th.col_heading {
#   text-align: left;
# }
# #T_fa285 td {
#   text-align: right;
# }
# </style>
# <table id="T_fa285">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa285_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_fa285_level0_col1" class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa285_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa285_row0_col0" class="data row0 col0" >time</td>
#       <td id="T_fa285_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa285_row1_col0" class="data row1 col0" >temperature_2m_max (°C)</td>
#       <td id="T_fa285_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa285_row2_col0" class="data row2 col0" >temperature_2m_min (°C)</td>
#       <td id="T_fa285_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa285_row3_col0" class="data row3 col0" >precipitation_sum (mm)</td>
#       <td id="T_fa285_row3_col1" class="data row3 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa285_row4_col0" class="data row4 col0" >precipitation_hours (h)</td>
#       <td id="T_fa285_row4_col1" class="data row4 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa285_row5_col0" class="data row5 col0" >wind_speed_10m_max (km/h)</td>
#       <td id="T_fa285_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa285_row6_col0" class="data row6 col0" >wind_direction_10m_dominant (°)</td>
#       <td id="T_fa285_row6_col1" class="data row6 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa285_row7_col0" class="data row7 col0" >shortwave_radiation_sum (MJ/m²)</td>
#       <td id="T_fa285_row7_col1" class="data row7 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa285_row8_col0" class="data row8 col0" >temperature_2m_mean (°C)</td>
#       <td id="T_fa285_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa285_row9_col0" class="data row9 col0" >relative_humidity_2m_mean (%)</td>
#       <td id="T_fa285_row9_col1" class="data row9 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fa285_row10_col0" class="data row10 col0" >cloud_cover_mean (%)</td>
#       <td id="T_fa285_row10_col1" class="data row10 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fa285_row11_col0" class="data row11 col0" >surface_pressure_mean (hPa)</td>
#       <td id="T_fa285_row11_col1" class="data row11 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fa285_row12_col0" class="data row12 col0" >wind_gusts_10m_max (km/h)</td>
#       <td id="T_fa285_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fa285_row13_col0" class="data row13 col0" >winddirection_10m_dominant (°)</td>
#       <td id="T_fa285_row13_col1" class="data row13 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fa285_row14_col0" class="data row14 col0" >relative_humidity_2m_max (%)</td>
#       <td id="T_fa285_row14_col1" class="data row14 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fa285_row15_col0" class="data row15 col0" >relative_humidity_2m_min (%)</td>
#       <td id="T_fa285_row15_col1" class="data row15 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fa285_row16_col0" class="data row16 col0" >cloud_cover_max (%)</td>
#       <td id="T_fa285_row16_col1" class="data row16 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fa285_row17_col0" class="data row17 col0" >cloud_cover_min (%)</td>
#       <td id="T_fa285_row17_col1" class="data row17 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fa285_row18_col0" class="data row18 col0" >wind_gusts_10m_mean (km/h)</td>
#       <td id="T_fa285_row18_col1" class="data row18 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fa285_row19_col0" class="data row19 col0" >wind_speed_10m_mean (km/h)</td>
#       <td id="T_fa285_row19_col1" class="data row19 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fa285_row20_col0" class="data row20 col0" >wind_gusts_10m_min (km/h)</td>
#       <td id="T_fa285_row20_col1" class="data row20 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fa285_row21_col0" class="data row21 col0" >wind_speed_10m_min (km/h)</td>
#       <td id="T_fa285_row21_col1" class="data row21 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fa285_row22_col0" class="data row22 col0" >surface_pressure_max (hPa)</td>
#       <td id="T_fa285_row22_col1" class="data row22 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fa285_row23_col0" class="data row23 col0" >surface_pressure_min (hPa)</td>
#       <td id="T_fa285_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fa285_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fa285_row24_col0" class="data row24 col0" >lokasi</td>
#       <td id="T_fa285_row24_col1" class="data row24 col1" >object</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Tidak ada data null
# ✅ Tidak ada data duplikat
# <style type="text/css">
# #T_fd603 th.row_heading {
#   text-align: left;
# }
# #T_fd603  th.col_heading {
#   text-align: left;
# }
# #T_fd603 td {
#   text-align: right;
# }
# </style>
# <table id="T_fd603">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd603_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_fd603_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_fd603_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_fd603_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_fd603_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_fd603_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_fd603_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_fd603_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd603_level0_row0" class="row_heading level0 row0" >temperature_2m_max (°C)</th>
#       <td id="T_fd603_row0_col0" class="data row0 col0" >28610.000000</td>
#       <td id="T_fd603_row0_col1" class="data row0 col1" >30.648399</td>
#       <td id="T_fd603_row0_col2" class="data row0 col2" >1.821691</td>
#       <td id="T_fd603_row0_col3" class="data row0 col3" >23.900000</td>
#       <td id="T_fd603_row0_col4" class="data row0 col4" >29.500000</td>
#       <td id="T_fd603_row0_col5" class="data row0 col5" >30.500000</td>
#       <td id="T_fd603_row0_col6" class="data row0 col6" >31.800000</td>
#       <td id="T_fd603_row0_col7" class="data row0 col7" >38.800000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row1" class="row_heading level0 row1" >temperature_2m_min (°C)</th>
#       <td id="T_fd603_row1_col0" class="data row1 col0" >28610.000000</td>
#       <td id="T_fd603_row1_col1" class="data row1 col1" >23.523957</td>
#       <td id="T_fd603_row1_col2" class="data row1 col2" >0.862093</td>
#       <td id="T_fd603_row1_col3" class="data row1 col3" >18.500000</td>
#       <td id="T_fd603_row1_col4" class="data row1 col4" >23.000000</td>
#       <td id="T_fd603_row1_col5" class="data row1 col5" >23.600000</td>
#       <td id="T_fd603_row1_col6" class="data row1 col6" >24.100000</td>
#       <td id="T_fd603_row1_col7" class="data row1 col7" >26.400000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row2" class="row_heading level0 row2" >precipitation_sum (mm)</th>
#       <td id="T_fd603_row2_col0" class="data row2 col0" >28610.000000</td>
#       <td id="T_fd603_row2_col1" class="data row2 col1" >6.499259</td>
#       <td id="T_fd603_row2_col2" class="data row2 col2" >7.959182</td>
#       <td id="T_fd603_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_fd603_row2_col4" class="data row2 col4" >0.800000</td>
#       <td id="T_fd603_row2_col5" class="data row2 col5" >3.800000</td>
#       <td id="T_fd603_row2_col6" class="data row2 col6" >9.600000</td>
#       <td id="T_fd603_row2_col7" class="data row2 col7" >117.700000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row3" class="row_heading level0 row3" >precipitation_hours (h)</th>
#       <td id="T_fd603_row3_col0" class="data row3 col0" >28610.000000</td>
#       <td id="T_fd603_row3_col1" class="data row3 col1" >8.126075</td>
#       <td id="T_fd603_row3_col2" class="data row3 col2" >5.980301</td>
#       <td id="T_fd603_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_fd603_row3_col4" class="data row3 col4" >3.000000</td>
#       <td id="T_fd603_row3_col5" class="data row3 col5" >7.000000</td>
#       <td id="T_fd603_row3_col6" class="data row3 col6" >12.000000</td>
#       <td id="T_fd603_row3_col7" class="data row3 col7" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row4" class="row_heading level0 row4" >wind_speed_10m_max (km/h)</th>
#       <td id="T_fd603_row4_col0" class="data row4 col0" >28610.000000</td>
#       <td id="T_fd603_row4_col1" class="data row4 col1" >12.591846</td>
#       <td id="T_fd603_row4_col2" class="data row4 col2" >3.652951</td>
#       <td id="T_fd603_row4_col3" class="data row4 col3" >4.100000</td>
#       <td id="T_fd603_row4_col4" class="data row4 col4" >9.800000</td>
#       <td id="T_fd603_row4_col5" class="data row4 col5" >12.000000</td>
#       <td id="T_fd603_row4_col6" class="data row4 col6" >14.900000</td>
#       <td id="T_fd603_row4_col7" class="data row4 col7" >30.400000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row5" class="row_heading level0 row5" >wind_direction_10m_dominant (°)</th>
#       <td id="T_fd603_row5_col0" class="data row5 col0" >28610.000000</td>
#       <td id="T_fd603_row5_col1" class="data row5 col1" >178.957987</td>
#       <td id="T_fd603_row5_col2" class="data row5 col2" >96.550651</td>
#       <td id="T_fd603_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_fd603_row5_col4" class="data row5 col4" >91.000000</td>
#       <td id="T_fd603_row5_col5" class="data row5 col5" >184.000000</td>
#       <td id="T_fd603_row5_col6" class="data row5 col6" >266.000000</td>
#       <td id="T_fd603_row5_col7" class="data row5 col7" >360.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row6" class="row_heading level0 row6" >shortwave_radiation_sum (MJ/m²)</th>
#       <td id="T_fd603_row6_col0" class="data row6 col0" >28610.000000</td>
#       <td id="T_fd603_row6_col1" class="data row6 col1" >18.486990</td>
#       <td id="T_fd603_row6_col2" class="data row6 col2" >3.800085</td>
#       <td id="T_fd603_row6_col3" class="data row6 col3" >2.540000</td>
#       <td id="T_fd603_row6_col4" class="data row6 col4" >16.570000</td>
#       <td id="T_fd603_row6_col5" class="data row6 col5" >19.090000</td>
#       <td id="T_fd603_row6_col6" class="data row6 col6" >21.060000</td>
#       <td id="T_fd603_row6_col7" class="data row6 col7" >27.980000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row7" class="row_heading level0 row7" >temperature_2m_mean (°C)</th>
#       <td id="T_fd603_row7_col0" class="data row7 col0" >28610.000000</td>
#       <td id="T_fd603_row7_col1" class="data row7 col1" >26.598972</td>
#       <td id="T_fd603_row7_col2" class="data row7 col2" >0.954853</td>
#       <td id="T_fd603_row7_col3" class="data row7 col3" >23.100000</td>
#       <td id="T_fd603_row7_col4" class="data row7 col4" >26.000000</td>
#       <td id="T_fd603_row7_col5" class="data row7 col5" >26.550000</td>
#       <td id="T_fd603_row7_col6" class="data row7 col6" >27.200000</td>
#       <td id="T_fd603_row7_col7" class="data row7 col7" >30.500000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row8" class="row_heading level0 row8" >relative_humidity_2m_mean (%)</th>
#       <td id="T_fd603_row8_col0" class="data row8 col0" >28610.000000</td>
#       <td id="T_fd603_row8_col1" class="data row8 col1" >81.814925</td>
#       <td id="T_fd603_row8_col2" class="data row8 col2" >7.013838</td>
#       <td id="T_fd603_row8_col3" class="data row8 col3" >50.000000</td>
#       <td id="T_fd603_row8_col4" class="data row8 col4" >78.000000</td>
#       <td id="T_fd603_row8_col5" class="data row8 col5" >84.000000</td>
#       <td id="T_fd603_row8_col6" class="data row8 col6" >87.000000</td>
#       <td id="T_fd603_row8_col7" class="data row8 col7" >96.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row9" class="row_heading level0 row9" >cloud_cover_mean (%)</th>
#       <td id="T_fd603_row9_col0" class="data row9 col0" >28610.000000</td>
#       <td id="T_fd603_row9_col1" class="data row9 col1" >77.760154</td>
#       <td id="T_fd603_row9_col2" class="data row9 col2" >22.281477</td>
#       <td id="T_fd603_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_fd603_row9_col4" class="data row9 col4" >64.000000</td>
#       <td id="T_fd603_row9_col5" class="data row9 col5" >85.000000</td>
#       <td id="T_fd603_row9_col6" class="data row9 col6" >97.000000</td>
#       <td id="T_fd603_row9_col7" class="data row9 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd603_level0_row10" class="row_heading level0 row10" >surface_pressure_mean (hPa)</th>
#       <td id="T_fd603_row10_col0

# %%
column_schema = extract_single_schema(df_cuaca)
column_schema
# Out:
# {'columns': ['time',
#   'temperature_2m_max (°C)',
#   'temperature_2m_min (°C)',
#   'precipitation_sum (mm)',
#   'precipitation_hours (h)',
#   'wind_speed_10m_max (km/h)',
#   'wind_direction_10m_dominant (°)',
#   'shortwave_radiation_sum (MJ/m²)',
#   'temperature_2m_mean (°C)',
#   'relative_humidity_2m_mean (%)',
#   'cloud_cover_mean (%)',
#   'surface_pressure_mean (hPa)',
#   'wind_gusts_10m_max (km/h)',
#   'winddirection_10m_dominant (°)',
#   'relative_humidity_2m_max (%)',
#   'relative_humidity_2m_min (%)',
#   'cloud_cover_max (%)',
#   'cloud_cover_min (%)',
#   'wind_gusts_10m_mean (km/h)',
#   'wind_speed_10m_mean (km/h)',
#   'wind_gusts_10m_min (km/h)',
#   'wind_speed_10m_min (km/h)',
#   'surface_pressure_max (hPa)',
#   'surface_pressure_min (hPa)',
#   'lokasi'],
#  'n_columns': 25}

# %%
print("Total rows:", df_cuaca.shape[0])
print("Total columns:", df_cuaca.shape[1])
# Out:
# Total rows: 28610
# Total columns: 25
